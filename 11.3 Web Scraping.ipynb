# %% [markdown]
# # 11.3 Web Scraping
#
# **HTML**, which stands for "hypertext markup language", is an XML-like language for specifying the appearance of web pages. Each tag in HTML corresponds to a specific page element. For example:
#
# - `<img>` specifies an image. The path to the image file is specified in the `src=` attribute.
# - `<a>` specifies a hyperlink. The text enclosed between `<a>` and `</a>` is the text of the link that appears, while the URL is specified in the `href=` attribute of the tag.
# - `<table>` specifies a table. The rows of the table are specified by `<tr>` tags nested inside the `<table>` tag, while the cells in each row are specified by `<td>` tags nested inside each `<tr>` tag.
#
# Our goal in this section is not to teach you HTML to make a web page. You will learn just enough HTML to be able to scrape data programmatically from a web page.

# %% [markdown]
# # Inspecting HTML Source Code
#
# Suppose we want to scrape faculty information from the [Cal Poly Statistics Department directory](https://statistics.calpoly.edu/content/directory) (`https://statistics.calpoly.edu/content/directory`). Once we have identified a web page that we want to scrape, the next step is to study the HTML source code. All web browsers have a "View Source" or "Page Source" feature that will display the HTML source of a web page.
#
# Visit the web page above, and view the HTML source of that page. (You may have to search online to figure out how to view the page source in your favorite browser.) Scroll down until you find the HTML code for the table containing information about the name, office, phone, e-mail, and office hours of the faculty members.
#
# Notice how difficult it can be to find a page element in the HTML source. Many browsers allow you to right-click on a page element and jump to the part of the HTML source corresponding to that element.

# %% [markdown]
# # Web Scraping Using BeautifulSoup
#
# `BeautifulSoup` is a Python library that makes it easy to navigate an HTML document. Like with `lxml`, we can query tags by name or attribute, and we can narrow our search to the ancestors and descendants of specific tags. In fact, it is possible to use `lxml` with HTML documents, but many web sites have malformed HTML, and `lxml` is not very forgiving. `BeautifulSoup` handles malformed HTML more gracefully and is thus the library of choice.
#
# First, we issue an HTTP request to the URL to get the HTML source code.

# %%
import requests
response = requests.get("https://statistics.calpoly.edu/content/directory")

# %% [markdown]
# The HTML source is stored in the `.content` attribute of the response object. We pass this HTML source into `BeautifulSoup` to obtain a tree-like representation of the HTML document.

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(response.content, "html.parser")

# %% [markdown]
# Now we can search for tags within this HTML document, using tags like `.find_all()`. For example, we can find all tables on this page.

# %%
tables = soup.find_all("table")
len(tables)
# Out:
# 2

# %% [markdown]
# As a visual inspection of [the web page](https://statistics.calpoly.edu/content/StatisticsDirectory%26Office%20Hours) would confirm, there are 2 tables on the page, and we are interested in the second one.

# %%
table = tables[1]
table
# Out:
# <table cellspacing="0" class="directory backwhite" height="2667" summary="COSAM Dean's Office Staff" width="596"><tbody><tr><th scope="col" width="18%">
# <p>Name</p>
# </th>
# <th scope="col" width="8%">Office</th>
# <th scope="col" width="10%">Phone (805)</th>
# <th scope="col" width="20%">Email</th>
# <th scope="col" width="20%">
# <p>Office HoURS </p>
# </th>
# </tr><tr><td><a href="/Kelly-Bodwin"><strong>Kelly Bodwin</strong></a></td>
# <td><a href="https://maps.calpoly.edu/">25-106</a></td>
# <td>756-2450</td>
# <td><a href="mailto:kbodwin@calpoly.edu">kbodwin@calpoly.edu</a></td>
# <td>
# <p><strong>TWR 2:30-3:30pm</strong></p>
# <p><strong>W 2:30-4:30pm</strong></p>
# </td>
# </tr><tr><td><a href="/Matt-Carlton"><strong>Matt Carlton</strong></a></td>
# <td><a href="https://maps.calpoly.edu/">25-101</a></td>
# <td>756-7076</td>
# <td><a href="mailto:rmlau@calpoly.edu">mcarlton@calpoly.edu</a></td>
# <td>
# <p><strong>M 1:10-2pm</strong></p>
# <p><strong>WR 2:10-3pm</strong></p>
# <p><strong>F 4:10-6pm Zoom</strong></p>
# <p>See Canvas for Zoom Link.</p>
# </td>
# </tr><tr><td><a href="/Beth-Chance"><strong>Beth Chance</strong></a></td>
# <td><a href="https://maps.calpoly.edu/">25-235</a></td>
# <td>
# <p>756-2961</p>
# </td>
# <td><a href="mailto:bchance@calpoly.edu">bchance@calpoly.edu</a></td>
# <td>
# <p><strong>M 7:10-8pm</strong></p>
# <p><strong>TR 1:10-2pm</strong></p>
# <p><strong>W 10-11am</strong></p>
# <p><strong>F 11-12pm</strong></p>
# <p>For <a href="https://calendly.com/iambethchance">Zoom appt.</a></p>
# </td>
# </tr><tr><td><a href="/Nianpin-Cheng"><strong>Nianpin Cheng</strong></a></td>
# <td><a href="http://maps.calpoly.edu/">92M-A103</a></td>
# <td>756-1180</td>
# <td><a href="mailto:ncheng@calpoly.edu">ncheng@calpoly.edu</a></td>
# <td>
# <p><strong>TW 10:10-11am</strong></p>
# <p>See Canvas for Zoom Link.</p>
# </td>
# </tr><tr><td><a href="/Olga-Dekhtyar"><strong>Olga Dekhtyar</strong></a></td>
# <td><a href="https://maps.calpoly.edu/">25-225</a></td>
# <td>756-6354</td>
# <td><a href="mailto:odekhtya@calpoly.edu">odekhtya@calpoly.edu</a></td>
# <td>
# <p><strong>TR 11:10-12pm</strong></p>
# <p><strong>R 5:00-6pm</strong></p>
# <p>By appt.</p>
# <p><strong>F 10:10-12pm </strong>in 38-123A</p>
# <p>See Canvas for Zoom link.</p>
# </td>
# </tr><tr><td><a href="/Jimmy-Doi"><strong>Jimmy Doi</strong></a></td>
# <td><a href="https://maps.calpoly.edu/">25-108</a></td>
# <td>756-2901</td>
# <td><a href="mailto:jdoi@calpoly.edu">jdoi@calpoly.edu</a></td>
# <td>
# <p><strong>M 11:10-12pm</strong></p>
# <p><strong>TR 10:10-11am</strong></p>
# <p>See Canvas for Zoom link</p>
# </td>
# </tr><tr><td><a href="/Samuel-Frame"><strong>Samuel Frame</strong></a></td>
# <td><a href="https://maps.calpoly.edu/">25-121</a></td>
# <td>756-5802</td>
# <td><a href="mailto:sframe@calpoly.edu">sframe@calpoly.edu</a></td>
# <td>
# <p><strong>MTWR 2:10-3pm</strong></p>
# </td>
# </tr><tr><td><a href="/Hunter-Glanz"><strong>Hunter Glanz</strong></a></td>
# <td><a href="https://maps.calpoly.edu/">25-111</a></td>
# <td>756-2792</td>
# <td>
# <p><a href="mailto:hglanz@calpoly.edu">hglanz@calpoly.edu</a></p>
# </td>
# <td>
# <p><strong>TR 3:10-4pm</strong></p>
# <p>See Canvas for Zoom link. </p>
# </td>
# </tr><tr><td><a href="https://statistics.calpoly.edu/giri-gopalan"><strong>Giri Gopalan</strong></a></td>
# <td><a href="https://maps.calpoly.edu/">25-103</a></td>
# <td>756-2715</td>
# <td><a href="mailto:ggopalan@calpoly.edu">ggopalan@calpoly.edu</a></td>
# <td>
# <p><strong>MR 2:00-3pm</strong></p>
# <p>See Canvas for Zoom link.</p>
# </td>
# </tr><tr><td><a href="https://statistics.calpoly.edu/bille-jo-grant"><strong>Billie-Jo Grant</strong></a></td>
# <td><a href="https://maps.calpoly.edu/">25-221</a></td>
# <td>756-2709</td>
# <td><a href="mailto:bgrant02@calpoly.edu">bgrant02@calpoly.edu</a></td>
# <td>
# <p><strong>MW 1:00-2pm</strong></p>
# </td>
# </tr><tr><td><a href="https://statistics.calpoly.edu/bret-holladay"><strong>Bret Holladay</strong></a></td>
# <td><a href="https://maps.calpoly.edu/">25-122</a></td>
# <td>756-2709</td>
# <td><a href="mailto:bahollad@calpoly.edu">bahollad@calpoly.edu</a></td>
# <td>
# <p><strong>MR 1:40-2:40pm</strong></p>
# <p>See Canvas for Zoom link.</p>
# </td>
# </tr><tr><td><strong>Felicia Korengel</strong></td>
# <td><a href="http://maps.calpoly.edu/">25-215</a></td>
# <td>756-2709</td>
# <td><a href="mailto:fkorenge@calpoly.edu">fkorenge@calpoly.edu</a></td>
# <td>
# <p><strong>T 12:30-2pm</strong></p>
# <p><strong>W 4:30-6pm </strong></p>
# <p><strong>R 11:10-12:30pm</strong> </p>
# </td>
# </tr><tr><td><strong><a href="/Ulric-Lund">Ulric Lund</a></strong></td>
# <td><a href="https://maps.calpoly.edu/">25-236</a></td>
# <td>756-6122</td>
# <td><a href="mailto:ulund@calpoly.edu">ulund@calpoly.edu</a></td>
# <td>
# <p><strong>TR 9:30-11am</strong></p>
# <p><strong>F 1:30-2:30pm </strong></p>
# <p>See Canvas for Zoom link.</p>
# </td>
# </tr><tr><td><a href="/Karen-McGaughey"><strong>Karen McGaughey</strong></a></td>
# <td><a href="https://maps.calpoly.edu/">25-102</a></td>
# <td>756-6578</td>
# <td><a href="mailto:kmcgaugh@calpoly.edu">kmcgaugh@calpoly.edu</a></td>
# <td>
# <p><strong>MW 1:10-1:55pm</strong></p>
# <p><strong>RF 10:10-11am </strong></p>
# <p>Zoom</p>
# <p>See Canvas for Zoom link.</p>
# </td>
# </tr><tr><td>James Oksanish</td>
# <td><a href="http://maps.calpoly.edu/">25-119</a></td>
# <td>756-2709</td>
# <td><a href="mailto:joksanis@calpoly.edu">joksanis@calpoly.edu</a></td>
# <td>
# <p><strong>MTWR 4:15-5:30pm</strong></p>
# </td>
# </tr><tr><td><strong><a href="/Rebecca-Ottesen">Rebecca Ottesen</a></strong></td>
# <td><a href="http://maps.calpoly.edu/">25-119</a></td>
# <td>
# <p>756-2709</p>
# </td>
# <td>
# <p><a href="mailto:rottesen@calpoly.edu">rottesen@calpoly.edu</a></p>
# </td>
# <td>
# <p><strong>M 5-6pm</strong></p>
# <p>See Canvas for Zoom link.</p>
# </td>
# </tr><tr><td><strong><a href="/Steve-Rein">Steve Rein</a></strong></td>
# <td><a href="https://maps.calpoly.edu/">25-234</a></td>
# <td>756-2941</td>
# <td><a href="mailto:srein@calpoly.edu">srein@calpoly.edu</a></td>
# <td>
# <p><strong>MW 2:40-3:30pm</strong></p>
# <p>(in-person)</p>
# <p><strong>TRF (</strong><a href="https://calendly.com/stevenrein/15min">Calendly appt.)</a></p>
# </td>
# </tr><tr><td><strong><a href="/Kevin-Ross">Kevin Ross</a></strong></td>
# <td><a href="https://maps.calpoly.edu/">25-237</a></td>
# <td>756-5739</td>
# <td><a href="mailto:kjross@calpoly.edu">kjross@calpoly.edu</a></td>
# <td> </td>
# </tr><tr><td>
# <p><strong><a href="/allan-rossman">Allan Rossman</a></strong></p>
# </td>
# <td>
# <p><a href="https://maps.calpoly.edu/">116-221</a></p>
# </td>
# <td>756-2709</td>
# <td><a href="mailto:arossman@calpoly.edu">arossman@calpoly.edu</a></td>
# <td>
# <p><strong>MW 12:30-1:30pm</strong></p>
# <p><strong>TR 2:30-3:30pm</strong></p>
# </td>
# </tr><tr><td>
# <p><strong><a href="/Soma-Roy">Soma Roy</a></strong></p>
# </td>
# <td><a href="https://maps.calpoly.edu/">25-104</a></td>
# <td>
# <p>756-5250</p>
# </td>
# <td><a href="mailto:soroy@calpoly.edu">soroy@calpoly.edu</a></td>
# <td>
# <p><strong>M 11:10-12pm</strong></p>
# <p><strong>W 12:10-1pm</strong></p>
# <p><strong>R 12:10-1pm</strong></p>
# <p>(in-person)</p>
# <p><strong>F 2:10-3pm</strong></p>
# <p>See Canvas for Zoom link.</p>
# </td>
# </tr><tr><td><strong><a href="/Anelise-Sabbag">Anelise Sabbag</a></strong></td>
# <td>
# <p><a href="https://maps.calpoly.edu/">25-222</a></p>
# </td>
# <td>756-5562</td>
# <td>
# <p><a href="mailto:asabbag@calpoly.edu">asabbag@calpoly.edu</a></p>
# </td>
# <td>
# <p><strong>MW 11:10-12pm </strong></p>
# <p>(in-person)</p>
# <p><strong>TR 10:10-11am</strong></p>
# <p>See Canvas for Zoom link.</p>
# </td>
# </tr><tr><td><strong><a href="https://statistics.calpoly.edu/maddie-schroth-glanz">Maddie Schroth-Glanz</a></strong></td>
# <td><a href="https://maps.calpoly.edu/">25-223</a></td>
# <td>
# <p>756-6310</p>
# </td>
# <td><a href="mailto:mschroth@calpoly.edu">mschroth@calpoly.edu</a></td>
# <td>
# <p><strong>MW 10:10-11am</strong><br/>
# 			(in person)</p>
# <p><strong>T 12:10-1pm</strong></p>
# <p><strong>W 11:10-12pm </strong></p>
# <p>Zoom</p>
# <p>See Canvas for Zoom link. </p>
# </td>
# </tr><tr><td><strong>Sonja Schuster</strong></td>
# <td><a href="http://maps.calpoly.edu/">25-119</a></td>
# <td>756-2709</td>
# <td><a href="mailto:sschuste@calpoly.edu">sschuste@calpoly.edu</a></td>
# <td>
# <p><strong>T 11:10-12pm</strong></p>
# <p><strong>F 9:10-10am</strong></p>
# <p>See Canvas for Zoom link. </p>
# </td>
# </tr><tr><td><strong><a href="/Jeff-Sklar">Jeffrey Sklar</a></strong></td>
# <td>
# <p><a href="https://maps.calpoly.edu/">25-110</a></p>
# </td>
# <td>756-6353</td>
# <td><a href="mailto:jsklar@calpoly.edu">jsklar@calpoly.edu</a></td>
# <td>
# <p><strong>M 10:10-11:30am</strong></p>
# <p><strong>W 1:30-2:30pm</strong></p>
# <p><strong>R 10:10-11:30am</strong></p>
# <p>See Canvas for more info. </p>
# </td>
# </tr><tr><td><strong>Bob Smidt</strong></td>
# <td><a href="https://maps.calpoly.edu/">25-107D</a></td>
# <td>756-2709</td>
# <td><a href="mailto:rsmidt@calpoly.edu">rsmidt@calpoly.edu</a></td>
# <td>N/A</td>
# </tr><tr><td><strong><a href="/Heather-Smith">Heather Smith</a></strong></td>
# <td><a href="https://maps.calpoly.edu/">25-112</a></td>
# <td>756-6128</td>
# <td><a href="mailto: hsmith@calpoly.edu">hsmith@calpoly.edu</a></td>
# <td>
# <p><strong>MW 11:10-12pm &amp; 5:10-6pm </strong></p>
# <p>Zoom</p>
# <p><strong>TRF </strong>(by appt.)</p>
# <p>E-mail for appts.</p>
# <p>For <a href="https://calendly.com/hsmithcalpoly/prof-smith-office-hour-meeting">Zoom appt.</a></p>
# </td>
# </tr><tr><td>Harsimran Somal</td>
# <td><a href="http://maps.calpoly.edu/">25-207</a></td>
# <td>756-2709</td>
# <td><a href="mailto:hsomal@calpoly.edu">hsomal@calpoly.edu</a></td>
# <td>
# <p><strong>MTWR 1-2pm</strong></p>
# </td>
# </tr><tr><td><strong><a href="/Dennis-Sun">Dennis Sun</a></strong></td>
# <td><a href="https://maps.calpoly.edu/">25-109</a></td>
# <td>756-5877</td>
# <td><a href="mailto:dsun09@calpoly.edu">dsun09@calpoly.edu</a></td>
# <td>
# <p> </p>
# </td>
# </tr><tr><td><strong><a href="https://statistics.calpoly.edu/allison-theobold">Allison Theobold</a></strong></td>
# <td><a href="https://maps.calpoly.edu/">25-105</a></td>
# <td>756-5539</td>
# <td><a href="mailto:atheobol@calpoly.edu">atheobol@calpoly.edu</a></td>
# <td>
# <p><strong>TR 1:45-2:45pm</strong><br/>
# 			(in person)</p>
# <p><strong>TR 2:45-3:15pm </strong>(Zoom)</p>
# <p><a href="https://calendly.com/allisontheobold/office-hour-appointment">Zoom appt.</a></p>
# </td>
# </tr><tr><td><strong><a href="/John-Walker">John Walker</a></strong></td>
# <td><a href="https://maps.calpoly.edu/">25-226</a></td>
# <td>756-7128</td>
# <td><a href="mailto:jwalker@calpoly.edu">jwalker@calpoly.edu</a></td>
# <td>
# <p><strong>M 4:10-5pm</strong></p>
# <p><strong>TF 3:10-4pm</strong></p>
# <p><strong>R 2:10-3pm</strong></p>
# <p>See Canvas for Zoom link.</p>
# </td>
# </tr><tr><td><strong>Yi-Hui Wang</strong></td>
# <td><a href="http://maps.calpoly.edu/">25-207D</a></td>
# <td>756-2709</td>
# <td><a href="mailto:alwaller@calpoly.edu">y</a><a href="mailto:ywang59@calpoly.edu">wang59@calpoly.edu</a></td>
# <td> </td>
# </tr><tr><td><strong>Immanuel Williams</strong></td>
# <td><a href="https://maps.calpoly.edu/">25-113</a></td>
# <td>756-2709</td>
# <td><a href="mailto:imwillia@calpoly.edu">imwillia@calpoly.edu</a></td>
# <td>
# <p><strong>MTWRF 11-12pm</strong></p>
# </td>
# </tr></tbody></table>

# %% [markdown]
# There is one faculty member per row, except for the first row, which is the header. We iterate over all rows except for the first, extracting information about each faculty to append to `rows`, which we will eventually turn into a `DataFrame`. As you read the code below, refer to the HTML source above, so that you understand what each line is doing. In particular, ask yourself the following questions:
#
# - `cells[0]` represents a `<td>` tag. Why do we need to call `.find("strong")` within this tag to get the name of the faculty member?
# - For the most part, `link` is a hyperlink whose text is the faculty's office number. But for some faculty, `link` is `None`. For which faculty is this the case and why?
#
# You are encouraged to add `print()` statements inside the `for` loop to check your understanding of each line of code.

# %%
rows = []
for faculty in table.find_all("tr")[1:]:
    # Get all the cells in the row.
    cells = faculty.find_all("td")
    
    # The information we need is the text between tags.
    name_tag = cells[0].find("strong") or cells[0]
    name = name_tag.text
    
    link = cells[1].find("a")
    office = link.text
    # office = cells[1].text if link is None else link.text
    
    email_tag = cells[3].find("a") or cells[3]
    email = email_tag.text
    
    # Append this data.
    rows.append({
        "name": name,
        "office": office,
        "email": email
    })

# %% [markdown]
# In the code above, observe that `.find_all()` returns a list with all matching tags, while `.find()` returns only the first matching tag. If no matching tags are found, then `.find_all()` will return an empty list `[]`, while `.find()` will return `None`.
#
# Finally, we turn `rows` into a `DataFrame`.

# %%
import pandas as pd
pd.DataFrame(rows)
# Out:
#                     name    office                 email
# 0           Kelly Bodwin    25-106   kbodwin@calpoly.edu
# 1           Matt Carlton    25-101  mcarlton@calpoly.edu
# 2            Beth Chance    25-235   bchance@calpoly.edu
# 3          Nianpin Cheng  92M-A103    ncheng@calpoly.edu
# 4          Olga Dekhtyar    25-225  odekhtya@calpoly.edu
# 5              Jimmy Doi    25-108      jdoi@calpoly.edu
# 6           Samuel Frame    25-121    sframe@calpoly.edu
# 7           Hunter Glanz    25-111    hglanz@calpoly.edu
# 8           Giri Gopalan    25-103  ggopalan@calpoly.edu
# 9        Billie-Jo Grant    25-221  bgrant02@calpoly.edu
# 10         Bret Holladay    25-122  bahollad@calpoly.edu
# 11      Felicia Korengel    25-215  fkorenge@calpoly.edu
# 12            Ulric Lund    25-236     ulund@calpoly.edu
# 13       Karen McGaughey    25-102  kmcgaugh@calpoly.edu
# 14        James Oksanish    25-119  joksanis@calpoly.edu
# 15       Rebecca Ottesen    25-119  rottesen@calpoly.edu
# 16            Steve Rein    25-234     srein@calpoly.edu
# 17            Kevin Ross    25-237    kjross@calpoly.edu
# 18         Allan Rossman   116-221  arossman@calpoly.edu
# 19              Soma Roy    25-104     soroy@calpoly.edu
# 20        Anelise Sabbag    25-222   asabbag@calpoly.edu
# 21  Maddie Schroth-Glanz    25-223  mschroth@calpoly.edu
# 22        Sonja Schuster    25-119  sschuste@calpoly.edu
# 23         Jeffrey Sklar    25-110    jsklar@calpoly.edu
# 24             Bob Smidt   25-107D    rsmidt@calpoly.edu
# 25         Heather Smith    25-112    hsmith@calpoly.edu
# 26       Harsimran Somal    25-207    hsomal@calpoly.edu
# 27            Dennis Sun    25-109    dsun09@calpoly.edu
# 28      Allison Theobold    25-105  atheobol@calpoly.edu
# 29           John Walker    25-226   jwalker@calpoly.edu
# 30           Yi-Hui Wang   25-207D                     y
# 31     Immanuel Williams    25-113  imwillia@calpoly.edu

# %% [markdown]
# Now this data is ready for further processing.

# %% [markdown]
# # Ethical Enlightenment: `robots.txt`
#
# Web robots are crawling the web all the time. A website may want to restrict the robots from crawling specific pages. One reason is financial: each visit to a web page, by a human or a robot, costs the website money, and the website may prefer to save their limited bandwidth for human visitors. Another reason is privacy: a website may not want a search engine to preserve a snapshot of a page for all eternity.
#
# To specify what a web robot is and isn't allowed to crawl, most websites will place a text file named `robots.txt` in the top-level directory of the web server. For example, the Statistics department web page has a `robots.txt` file: https://statistics.calpoly.edu/robots.txt
#
# The format of the `robots.txt` file should be self-explanatory, but you can read a full specification of the standard here: http://www.robotstxt.org/robotstxt.html. As you scrape websites using your web robot, always check the `robots.txt` file first, to make sure that you are respecting the wishes of the website owner.

# %% [markdown]
# # Exercises

# %% [markdown]
# 1\. The [Cal Poly course catalog](http://catalog.calpoly.edu/collegesandprograms/collegeofsciencemathematics/statistics/#courseinventory) (`http://catalog.calpoly.edu/collegesandprograms/collegeofsciencemathematics/statistics/#courseinventory`) contains a list of courses offered by the Statistics department. Scrape this website to obtain a `DataFrame`, where the unit of observation is a course. Use this `DataFrame` to answer the following questions:
#
# - How many 300-level courses does the Statistics department offer?
# -How many three-unit courses are offered?

# %%
response = requests.get("http://catalog.calpoly.edu/collegesandprograms/collegeofsciencemathematics/statistics/#courseinventory")
soup = BeautifulSoup(response.content, "html.parser")
course_titles = soup.find_all(class_ = "courseblocktitle")
course_titles[0]
# Out:
# <p class="courseblocktitle"><strong>DATA 301. Introduction to Data Science.
# <span class="courseblockhours">4 units
# </span></strong></p>

# %%
courses = []
for course in course_titles:
    header = course.find("strong")
    
    # The information we need is the text between tags.
    title = header.text

    split_title = title.split(".")
    course_name = split_title[1]

    split_keys = split_title[0].split()
    course_key = split_keys[0]
    course_num = split_keys[1]

    unit_string = split_title[2].strip().split()
    units = unit_string[0]

    courses.append({
        "course_key": course_key,
        "course_name": course_name,
        "course_num": course_num,
        "units": units
    })

# %%
course_df = pd.DataFrame(courses)
course_df
# Out:
#    course_key                                course_name course_num units
# 0        DATA               Introduction to Data Science        301     4
# 1        DATA            Data Science Process and Ethics        401     3
# 2        DATA   Mathematical Foundations of Data Science        402     3
# 3        DATA           Data Science Projects Laboratory        403     1
# 4        DATA                  Bioinformatics Capstone I        441     2
# ..        ...                                        ...        ...   ...
# 68       STAT                Statistical Learning with R        551     4
# 69       STAT              Graduate Consulting Practicum        566     2
# 70       STAT                   Selected Advanced Topics        570   1-4
# 71       STAT             Graduate Seminar in Statistics        590     1
# 72       STAT                                     Thesis        599   1-4
#
# [73 rows x 4 columns]

# %%
df_stat = course_df[course_df["course_key"] == "STAT"]
df_stat["course_level"] = df_stat["course_num"].str.get(0)
df_stat
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#    course_key                                        course_name course_num  \
# 9        STAT              Introduction to Statistical Reasoning        130
# 10       STAT       Introduction to the Discipline of Statistics        150
# 11       STAT                Special Problems for Undergraduates        200
# 12       STAT   Introduction to Statistical Concepts and Methods        217
# 13       STAT           Applied Statistics for the Life Sciences        218
# ..        ...                                                ...        ...
# 68       STAT                        Statistical Learning with R        551
# 69       STAT                      Graduate Consulting Practicum        566
# 70       STAT                           Selected Advanced Topics        570
# 71       STAT                     Graduate Seminar in Statistics        590
# 72       STAT                                             Thesis        599
#
#    units course_level
# 9      4            1
# 10     2            1
# 11   1-2            2
# 12     4            2
# 13     4            2
# ..   ...          ...
# 68     4            5
# 69     2            5
# 70   1-4            5
# 71     1            5
# 72   1-4            5
#
# [64 rows x 5 columns]

# %%
df_stat["course_level"].value_counts()
# Out:
# 4    25
# 5    17
# 3    14
# 2     6
# 1     2
# Name: course_level, dtype: int64

# %%
df_stat["units"].value_counts()
# Out:
# 4      46
# 2       6
# 1-4     5
# 1-2     2
# 1       2
# 5       1
# 6       1
# 12      1
# Name: units, dtype: int64

# %% [markdown]
# The statistics department offers 14 300 level classes and there are no exact 3 unit classes but 7 total that could have 3 units (either 1-4 or 1-2)
